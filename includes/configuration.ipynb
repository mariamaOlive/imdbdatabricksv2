# %%
catalog_folder_path = 'abfss://imdbdev@dbximdbdata.dfs.core.windows.net'
bronze_folder_path = 'abfss://bronze@dbximdbdata.dfs.core.windows.net'
silver_folder_path = 'abfss://silver@dbximdbdata.dfs.core.windows.net'
gold_folder_path = 'abfss://gold@dbximdbdata.dfs.core.windows.net'
